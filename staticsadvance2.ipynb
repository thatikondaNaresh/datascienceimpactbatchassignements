# %%
Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.
Probability Mass Function (PMF): This is used for discrete random variables and gives the probability that a discrete random variable is exactly equal to some value. Mathematically, for a discrete random variable 

Example: Consider rolling a fair six-sided die. The PMF for this scenario would give the probability of rolling each possible number from 1 to 6.

Probability Density Function (PDF): This is used for continuous random variables and describes the relative likelihood for a continuous random variable to take on a given value. For a continuous random variable 

Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?
Cumulative Density Function (CDF): This function gives the probability that a random variable 
F(x)=P(X≤x).

Example: For a fair six-sided die, the CDF would give the cumulative probabilities of rolling 1, 2, 3, 4, 5, and 6.

Importance: CDF is used to understand the distribution of a random variable over its entire range. It provides a complete picture of how likely values are distributed across the variable's range.

Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.
The normal distribution is used as a model in many real-world situations where the data tends to cluster around a central value with no bias towards left or right tails. Some examples include:

Heights or weights of people in a large population.
Measurement errors.
IQ scores.
Parameters:

Mean (
𝜇
μ): Determines the center or location of the distribution.
Standard Deviation (
𝜎
σ): Measures the spread or dispersion of the data around the mean.
The shape of the normal distribution is bell-shaped and symmetrical around the mean. The spread (standard deviation) controls how wide or narrow the bell curve is, while the mean shifts the entire curve left or right along the x-axis.
Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.
Importance:

Normal distribution is important because many natural processes and measurements tend to follow this distribution.
It simplifies statistical analysis because its properties are well-understood.
Examples:

Heights of people in a population.
IQ scores in a large group of people.
Measurement errors in scientific experiments.
Q5: What is Bernoulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?
Bernoulli Distribution: It represents the probability distribution of a random variable which takes the value 1 with probability 
Example: A coin toss can be modeled using Bernoulli distribution, where 
𝑝
p is the probability of getting heads.

Difference:

Bernoulli Distribution: Describes a single trial with two possible outcomes (success or failure).
Binomial Distribution: Describes the number of successes (yes/no outcomes) in a fixed number of independent trials.
Q6: Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater than 60? Use the appropriate formula and show your calculations.
To find the probability 
−
0.8413
=
0.1587
P(X>60)=P(Z>1)=1−0.8413=0.1587

So, the probability that a randomly selected observation from this dataset is greater than 60 is approximately 
0.1587
0.1587 or 
15.87
%
15.87%.

Q7: Explain Uniform Distribution with an example.
Uniform Distribution: This distribution occurs when all outcomes or values in a range are equally likely to occur. It's characterized by a constant probability density function over a given range.

Example: Rolling a fair six-sided die is an example of a discrete uniform distribution where each outcome (1 through 6) has an equal probability of 
1
6
6
1
​
 .

Q8: What is the z score? State the importance of the z score.
Z Score: The z score (or standard score) measures how many standard deviations a data point is from the mean of a dataset. It's calculated as:

Importance: Z scores are important because they:

Standardize data, allowing for comparison across different datasets.
Help determine how unusual or typical a particular data point is within a distribution.
Aid in hypothesis testing and inferential statistics by providing a reference point for normal distribution.
Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.
Central Limit Theorem (CLT): The CLT states that the sampling distribution of the sample mean approaches a normal distribution as the sample size gets larger, regardless of the shape of the population distribution. It's a fundamental concept in statistics.

Significance: The CLT is significant because:

It allows us to use normal distribution assumptions for many statistical analyses, even when the population distribution is not normal.
It forms the basis for inferential statistics, hypothesis testing, and confidence intervals.
It demonstrates why the mean of a large sample is a good estimate of the population mean.
Q10: State the assumptions of the Central Limit Theorem.
The Central Limit Theorem assumes:

The sample size is sufficiently large (typically 
𝑛
≥
30
n≥30).
The observations are independent of each other.
The population from which the samples are drawn has a finite variance.
These assumptions ensure that the sampling distribution of the sample mean approximates a normal distribution.

# %%
Q1:

def f_test(data1, data2):
F = np.var(data1) / np.var(data2)
p = scipy.stats.f.sf(F, len(data1)-1, len(data2)-1)
return F, p

Q2:

def critical_F(alpha, df1, df2):
F_crit = scipy.stats.f.ppf(1-alpha/2, df1, df2)
return F_crit

Q3:

def f_test_simulation():
# generate random samples
sample1 = np.random.normal(0, 1, 100)
sample2 = np.random.normal(0, 2, 100)

# calculate F-value and p-value
F, p = f_test(sample1, sample2)

# output results
print("F-value:", F)
print("Degrees of freedom:", len(sample1)-1, len(sample2)-1)
print("p-value:", p)

Q4:

F, p = f_test(sample1, sample2)
print("F-value:", F)
print("p-value:", p)

Q5:

F, p = f_test(sample, np.sqrt(0.005))
print("F-value:", F)
print("p-value:", p)

Q6:

def mean_variance_F(df1, df2):
mean = df1 / (df1 - 2)
var = (2 * (df1 + df2 - 2)) / ((df1 - 2) * (df1 - 4))
return mean, var

Q7:

F, p = f_test(sample1, sample2)
print("F-value:", F)
print("p-value:", p)

Q8:

F, p = f_test(data_A, data_B)
print("F-value:", F)
print("p-value:", p)

Q9:

F, p = f_test(data_A, data_B)
print("F-value:", F)
print("p-value:", p)

# %%
Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
Estimation Statistics: Estimation in statistics refers to the process of using sample data to estimate the characteristics of a population. It involves calculating estimates of parameters such as means, proportions, variances, etc.

Point Estimate: A point estimate is a single value estimate of a population parameter based on sample data. For example, using the sample mean 

Interval Estimate: An interval estimate provides a range of values that, with a certain level of confidence, is believed to contain the true population parameter. It takes into account both the point estimate and the variability in the data.

Q2: Write a Python function to estimate the population mean using a sample mean and standard deviation.
Here's a Python function to estimate the population mean given a sample mean (
import math

def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    # Assuming sample_size is sufficiently large to approximate population
    z_critical = 1.96  # for 95% confidence interval (z-score for 95% CI)
    
    # Calculate standard error of the mean (SEM)
    sem = sample_std_dev / math.sqrt(sample_size)
    
    # Calculate margin of error (MoE)
    margin_of_error = z_critical * sem
    
    # Calculate confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    
    return (lower_bound, upper_bound)

# Example usage:
sample_mean = 500  # sample mean revenue
sample_std_dev = 50  # sample standard deviation
sample_size = 50  # sample size

lower, upper = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
print(f"Estimated population mean revenue (95% CI): {lower} to {upper}")
Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
Hypothesis Testing: Hypothesis testing is a statistical method used to make inferences about a population parameter based on sample data. It involves formulating a hypothesis about the population parameter, collecting data to test the hypothesis, and drawing conclusions based on the data.

Importance: Hypothesis testing is crucial in scientific research and decision-making because it allows us to:

Make decisions based on evidence rather than intuition.
Evaluate the effectiveness of interventions or treatments.
Test theories and validate or refute claims.
Q4: Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
Hypothesis:

​
 .
Q5: Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.
Here’s a Python script using the scipy.stats module to perform a two-sample t-test for independent samples:

import numpy as np
from scipy import stats

# Sample data (replace with actual data)
sample1 = np.array([85, 90, 88, 92, 87])
sample2 = np.array([78, 80, 79, 82, 81])

# Perform independent two-sample t-test
t_stat, p_value = stats.ttest_ind(sample1, sample2)

# Print results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: There is a significant difference between the means.")
else:
    print("Fail to reject null hypothesis: There is no significant difference between the means.")
Q6: What is a null and alternative hypothesis? Give some examples.
It represents the status quo or the absence of an effect. It states that there is no significant difference or relationship between variables.

The mean weight loss after a diet plan is 0 pounds.

 It contradicts the null hypothesis and suggests that there is an effect or difference between variables.

 The mean weight loss after a diet plan is greater than 0 pounds.

Q7: Write down the steps involved in hypothesis testing.
The steps involved in hypothesis testing are:


Choose Significance Level (
𝛼
α): Decide on the level of significance to determine when to reject the null hypothesis.

Collect Data: Gather relevant data through observations or experiments.

Calculate Test Statistic: Compute a test statistic (such as z-score, t-statistic) based on the sample data.

Determine Critical Region: Define the critical region (rejection region) based on the significance level and test type (one-tailed or two-tailed).

Compare Test Statistic and Critical Region: Compare the calculated test statistic with the critical value(s) to make a decision.

Draw Conclusion: Based on the comparison, either reject 
​
  in favor of 
​
  or fail to reject 
Q8: Define p-value and explain its significance in hypothesis testing.
P-value: The p-value is the probability of obtaining a test statistic at least as extreme as the one observed in the sample data, under the assumption that the null hypothesis (
is true. It measures the strength of evidence against the null hypothesis.

Significance: A lower p-value indicates stronger evidence against the null hypothesis, suggesting that the observed data is unlikely to occur if 

​
  is true. Typically, if the p-value is less than the chosen significance level (
𝛼
α), the null hypothesis is rejected.

Q9: Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.
Here's a Python code snippet to generate a t-distribution plot using matplotlib:


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Degrees of freedom
df = 10

# Generate x values for plotting
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)

# Plot t-distribution
plt.plot(x, t.pdf(x, df), 'r-', lw=2, alpha=0.6, label='t pdf')

plt.title(f'Student\'s t-Distribution (df={df})')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
Q10: Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.
Here’s a Python script using scipy.stats to perform a two-sample t-test for independent samples:

import numpy as np
from scipy import stats

# Generate two independent samples (replace with actual data)
sample1 = np.random.normal(loc=5, scale=2, size=30)
sample2 = np.random.normal(loc=5.5, scale=2, size=30)

# Perform two-sample t-test
t_stat, p_value = stats.ttest_ind(sample1, sample2)

# Print results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: There is a significant difference between the means.")
else:
    print("Fail to reject null hypothesis: There is no significant difference between the means.")
This script generates two independent normal distributions (sample1 and sample2) and performs a two-sample t-test to compare their means.

Q11: What is Student’s t distribution? When to use the t-Distribution.
Student's t-Distribution: The t-distribution (or Student's t-distribution) is a probability distribution that is used to estimate population parameters when the sample size is small or the population standard deviation is unknown.

When to use:

Use the t-distribution when the sample size is small (typically 
Use it when the population standard deviation is unknown and has to be estimated from the sample.
Q12: What is t-statistic? State the formula for t-statistic.
t-statistic: The t-statistic measures the difference between the sample mean and the null hypothesis mean, relative to the variability in the data (standard error of the mean).

x  is the null hypothesis mean, 
𝑠
s is the sample standard deviation, and 
𝑛
n is the sample size.

Q13: A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
Given:

To estimate the population mean with a 95% confidence interval:

import math

def estimate_population_mean(sample_mean, sample_std_dev, sample_size, confidence_level=0.95):
    # Calculate critical value (z-score for 95% confidence level)
    z_critical = 1.96  # approximately for 95% confidence level

    # Calculate standard error of the mean (SEM)
    sem = sample_std_dev / math.sqrt(sample_size)

    # Calculate margin of error (MoE)
    margin_of_error = z_critical * sem

    # Calculate confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return (lower_bound, upper_bound)

# Given data
sample_mean = 500
sample_std_dev = 50
sample_size = 50

# Estimate population mean with 95% confidence interval
lower, upper = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
print(f"Estimated population mean revenue (95% CI): {lower} to {upper}")
Q14: A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
Given:

​
 : The drug does not decrease blood pressure by 10 mmHg.
Alternative hypothesis 

​
 : The drug decreases blood pressure by 10 mmHg.
Sample mean 

Sample standard deviation 
Sample size 
Significance level 
𝛼
=
0.05
α=0.05
from scipy import stats

# Given data
sample_mean = 8
null_hypothesis_mean = 10
sample_std_dev = 3
sample_size = 100
alpha = 0.05

# Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(a=sample_mean, popmean=null_hypothesis_mean)

# Print results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret results
if p_value < alpha:
    print("Reject null hypothesis: The drug decreases blood pressure significantly.")
else:
    print("Fail to reject null hypothesis: There is no significant evidence that the drug decreases blood pressure.")
Q15: An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.
Given:

Null hypothesis 
​
 : The true mean weight 
𝜇
μ is 5 pounds.
Alternative hypothesis 
​
 : The true mean weight 
𝜇
μ is less than 5 pounds.
Sample mean 
ˉ
 =4.8
Sample standard deviation 
n=25
Significance level 
α=0.01
from scipy import stats

# Given data
sample_mean = 4.8
null_hypothesis_mean = 5
sample_std_dev = 0.5
sample_size = 25
alpha = 0.01

# Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(a=sample_mean, popmean=null_hypothesis_mean)

# Print results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret results
if p_value < alpha:
    print("Reject null hypothesis: The true mean weight is less than 5 pounds.")
else:
    print("Fail to reject null hypothesis: There is no significant evidence that the true mean weight is less than 5 pounds.")
Q16: Two groups of students are given different study materials to prepare for a test. The first group (
​
 =30) has a mean score of 80 with a standard deviation of 10, and the second group (
​
 =40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.
Given:

Null hypothesis 
 
​
  (population means for two groups are equal).
Alternative hypothesis 
​
  (population means for two groups are not equal).
Group 1: 
Significance level 
𝛼
=
0.01
α=0.01
from scipy import stats

# Given data
sample_mean1 = 80
sample_std_dev1 = 10
sample_size1 = 30

sample_mean2 = 75
sample_std_dev2 = 8
sample_size2 = 40

alpha = 0.01

# Perform two-sample t-test
t_stat, p_value = stats.ttest_ind_from_stats(mean1=sample_mean1, std1=sample_std_dev1, nobs1=sample_size1,
                                             mean2=sample_mean2, std2=sample_std_dev2, nobs2=sample_size2)

# Print results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret results
if p_value < alpha:
    print("Reject null hypothesis: There is a significant difference between the means of the two groups.")
else:
    print("Fail to reject null hypothesis: There is no significant difference between the means of the two groups.")
Q17: A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.
Given:

Sample mean 
 =4
Sample standard deviation 
𝑠
Sample size 
𝑛
=
50
n=50
Confidence level 
0.99
1−α=0.99
To estimate the population mean with a 99% confidence interval:

import math

def estimate_population_mean(sample_mean, sample_std_dev, sample_size, confidence_level=0.99):
    # Calculate critical value (z-score for 99% confidence level)
    z_critical = 2.576  # approximately for 99% confidence level

    # Calculate standard error of the mean (SEM)
    sem = sample_std_dev / math.sqrt(sample_size)

    # Calculate margin of error (MoE)
    margin_of_error = z_critical * sem

    # Calculate confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return (lower_bound, upper_bound)

# Given data
sample_mean = 4
sample_std_dev = 1.5
sample_size = 50

# Estimate population mean with 99% confidence interval
lower, upper = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
print(f"Estimated population mean number of ads watched (99% CI): {lower} to {upper}")

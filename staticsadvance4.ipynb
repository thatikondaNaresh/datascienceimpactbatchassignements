# %%
Q1:

- t-test: used when the population standard deviation is unknown, example: comparing the means of two groups of students on a test
- z-test: used when the population standard deviation is known, example: comparing the mean height of a sample of people to the known population mean height

Q2:

- One-tailed test: tests if the mean is greater than or less than a certain value
- Two-tailed test: tests if the mean is different from a certain value

Q3:

- Type 1 error: rejecting a true null hypothesis (example: falsely concluding a new drug is effective)
- Type 2 error: failing to reject a false null hypothesis (example: failing to detect a real effect of a new drug)

Q4:

- Bayes' theorem: P(A|B) = P(B|A) * P(A) / P(B)
- Example: given a positive test result, what is the probability of actually having the disease?

Q5:

- Confidence interval: a range of values within which the true population parameter is likely to lie
- Calculation: (sample mean) +/- (z-score * (standard deviation / sqrt(n)))
- Example: 95% CI for a sample mean of 50, standard deviation of 5, and n=100 is (45.6, 54.4)

Q6:

- Sample problem: given a prior probability of 0.1, new evidence with a likelihood ratio of 2, calculate the posterior probability
- Solution: P(A|B) = P(B|A) * P(A) / P(B) = 2 * 0.1 / 0.5 = 0.4

Q7:

- 95% CI for a sample mean of 50, standard deviation of 5, and n=100 is (45.6, 54.4)
- Interpretation: there is a 95% probability that the true population mean lies between 45.6 and 54.4

Q8:

- Margin of error: the maximum amount by which the sample mean may differ from the true population mean
- Sample size affects margin of error: larger sample size results in smaller margin of error
- Example: a larger sample size would result in a smaller margin of error in estimating the true proportion of people who are satisfied with their job

Q9:

- z-score = (75 - 70) / (5 / sqrt(1)) = 1.0
- Interpretation: the data point is 1 standard deviation above the population mean

Q10:

- t-test: t = (6 - 0) / (2.5 / sqrt(50)) = 2.4, p-value < 0.05, reject null hypothesis, drug is significantly effective

Q11:

- 95% CI for true proportion: (0.63, 0.67)

Q12:

- t-test: t = (85 - 82) / (sqrt((6^2/50) + (5^2/50))) = 2.2, p-value < 0.01, reject null hypothesis, teaching methods have a significant difference

Q13:

- 90% CI for true population mean: (62.1, 67.9)

Q14:

- t-test: t = (0.25 - 0) / (0.05 / sqrt(30)) = 2.5, p-value < 0.1, fail to reject null hypothesis, caffeine may not have a significant effect on reaction time

Please let me know if you need further explanations or details!
